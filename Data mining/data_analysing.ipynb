# %%
import pandas as pd
import numpy as np

# %%
vacancy = pd.read_csv("vacancy.csv")
pd.set_option('display.max_rows', None)
vacancy
# Out:
#                   salary                                              title  \
# 0     70 000 – 130 000 ₽                Аналитик данных (SQL, фармацевтика)
# 1    200 000 – 330 000 ₽  Старший аналитик / Руководитель группы количес...
# 2    130 000 – 150 000 ₽                                    Аналитик данных
# 3    200 000 – 280 000 ₽                       Аналитик базы данных, remote
# 4             до 3 000 $                     Data analyst / Аналитик данных
# 5           до 200 000 ₽                       Аналитик данных/Data analyst
# 6           от 120 000 ₽                                           Аналитик
# 7           до 200 000 ₽  Продуктовый аналитик/data analyst/аналитик данных
# 8            до 92 000 ₽                               Аналитик базы данных
# 9     90 000 – 130 000 ₽            Аналитик маркетинговых данных, удаленно
# 10    80 000 – 110 000 ₽                                           Аналитик
# ...
