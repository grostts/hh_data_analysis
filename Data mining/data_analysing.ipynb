# %%
import pandas as pd
import numpy as np

# %%
vacancy = pd.read_csv("vacancy.csv")
pd.set_option('display.max_rows', None)
vacancy
# Out:
#                                         salary  \
# 0                               No salary info
# 1                               No salary info
# 2                               No salary info
# 3                               No salary info
# 4                               No salary info
# 5                               No salary info
# 6                               No salary info
# 7                               No salary info
# 8                          от 50 000 ₽ на руки
# 9                               No salary info
# 10                              No salary info
# 11                              No salary info
# 12                              No salary info
# 13                              No salary info
# 14                              No salary info
# 15                              No salary info
# 16                              No salary info
# 17                              No salary info
# 18                              No salary info
# ...
